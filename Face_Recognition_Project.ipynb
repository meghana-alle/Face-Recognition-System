# %%
# !pip install opencv-python numpy pillow

# %%
import os

os.makedirs("dataset", exist_ok=True)
os.makedirs("trainer", exist_ok=True)

print("Folders created")

# %%
import cv2
import os

cam = cv2.VideoCapture(0)
detector = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

face_id = 1  # change this number for each person
count = 0

while True:
    ret, img = cam.read()
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = detector.detectMultiScale(gray, 1.3, 5)

    for (x,y,w,h) in faces:
        count += 1
        cv2.imwrite(f"dataset/User.{face_id}.{count}.jpg", gray[y:y+h,x:x+w])
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

    cv2.imshow('Collecting Faces', img)

    if cv2.waitKey(1) & 0xFF == ord('q') or count >= 50:
        break

cam.release()
cv2.destroyAllWindows()

# %%
import cv2
import os

cam = cv2.VideoCapture(0)

if not cam.isOpened():
    print("Webcam not accessible")
    exit()

detector = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

face_id = 1
count = 0

while True:
    ret, img = cam.read()
    if not ret:
        break

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = detector.detectMultiScale(gray, 1.3, 5)

    for (x,y,w,h) in faces:
        count += 1
        cv2.imwrite(f"dataset/User.{face_id}.{count}.jpg", gray[y:y+h,x:x+w])
        cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

    cv2.imshow("Collecting Faces", img)

    if cv2.waitKey(1) & 0xFF == ord('q') or count >= 50:
        break

cam.release()
cv2.destroyAllWindows()

# %%
import cv2
import os
import time

cam = cv2.VideoCapture(0)
time.sleep(2)  # allow camera to warm up

detector = cv2.CascadeClassifier(cv2.data.haarcascades + "haarcascade_frontalface_default.xml")

face_id = 1
count = 0

while True:
    ret, img = cam.read()
    if not ret:
        print("Frame not captured")
        break

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = detector.detectMultiScale(gray, 1.3, 5)

    for (x,y,w,h) in faces:
        count += 1
        cv2.imwrite(f"dataset/User.{face_id}.{count}.jpg", gray[y:y+h,x:x+w])
        cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)

    cv2.imshow("Collecting Faces", img)

    # Slow down capture (important)
    time.sleep(0.1)

    if count >= 30:   # 👈 reduce to 30 (more stable)
        break

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cam.release()
cv2.destroyAllWindows()
print("Face collection completed")

# %%
import cv2
import numpy as np
from PIL import Image
import os

recognizer = cv2.face.LBPHFaceRecognizer_create()
path = 'dataset'

def getImagesAndLabels(path):
    imagePaths = [os.path.join(path, f) for f in os.listdir(path)]
    faceSamples = []
    ids = []

    for imagePath in imagePaths:
        PIL_img = Image.open(imagePath).convert('L')
        img_numpy = np.array(PIL_img, 'uint8')
        id = int(os.path.split(imagePath)[-1].split(".")[1])
        faceSamples.append(img_numpy)
        ids.append(id)

    return faceSamples, ids

faces, ids = getImagesAndLabels(path)
recognizer.train(faces, np.array(ids))

os.makedirs("trainer", exist_ok=True)
recognizer.save('trainer/trainer.yml')

print("Model trained successfully")

# %%
# !pip uninstall opencv-python -y
# !pip install opencv-contrib-python

# %%
# !pip install opencv-contrib-python

# %%
Kernel → Restart Kernel & Clear Output

# %%
import cv2
print(cv2.__version__)
print(hasattr(cv2, "face"))

# %%
recognizer = cv2.face.LBPHFaceRecognizer_create()

# %%
recognizer.train(faces, np.array(ids))

# %%
import cv2
import numpy as np
from PIL import Image
import os

# Create recognizer
recognizer = cv2.face.LBPHFaceRecognizer_create()

# Dataset path
path = 'dataset'

def getImagesAndLabels(path):
    imagePaths = [os.path.join(path, f) for f in os.listdir(path)]
    faceSamples = []
    ids = []

    for imagePath in imagePaths:
        PIL_img = Image.open(imagePath).convert('L')
        img_numpy = np.array(PIL_img, 'uint8')

        # Extract ID from filename
        id = int(os.path.split(imagePath)[-1].split(".")[1])

        faceSamples.append(img_numpy)
        ids.append(id)

    return faceSamples, ids

# THIS is where faces & ids are created
faces, ids = getImagesAndLabels(path)

# Train model
recognizer.train(faces, np.array(ids))

# Save model
os.makedirs("trainer", exist_ok=True)
recognizer.save('trainer/trainer.yml')

print("Model trained successfully")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 30
#      27     return faceSamples, ids
#      29 # THIS is where faces & ids are created
# ---> 30 faces, ids = getImagesAndLabels(path)
#      32 # Train model
#      33 recognizer.train(faces, np.array(ids))
#
# Cell In[1], line 18, in getImagesAndLabels(path)
#      15 ids = []
#      17 for imagePath in imagePaths:
# ---> 18     PIL_img = Image.open(imagePath).convert('L')
#      19     img_numpy = np.array(PIL_img, 'uint8')
#      21     # Extract ID from filename
#
# File ~\anaconda3\Lib\site-packages\PIL\Image.py:3493, in open(fp, mode, formats)
#    3491 if is_path(fp):
#    3492     filename = os.fspath(fp)
# -> 3493     fp = builtins.open(filename, "rb")
#    3494     exclusive_fp = True
#    3495 else:
#
# PermissionError: [Errno 13] Permission denied: 'dataset\\.ipynb_checkpoints'

# %%
def getImagesAndLabels(path):
    imagePaths = [os.path.join(path, f) for f in os.listdir(path)]
    faceSamples = []
    ids = []

    for imagePath in imagePaths:
        # 🔴 SKIP non-image files and folders
        if not imagePath.lower().endswith(('.jpg', '.png', '.jpeg')):
            continue

        PIL_img = Image.open(imagePath).convert('L')
        img_numpy = np.array(PIL_img, 'uint8')

        id = int(os.path.split(imagePath)[-1].split(".")[1])
        faceSamples.append(img_numpy)
        ids.append(id)

    return faceSamples, ids

# %%
faces, ids = getImagesAndLabels(path)
recognizer.train(faces, np.array(ids))
recognizer.save('trainer/trainer.yml')
print("Model trained successfully")
# Out:
# Model trained successfully

# %%
import cv2

recognizer = cv2.face.LBPHFaceRecognizer_create()
recognizer.read('trainer/trainer.yml')

faceCascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
)

cam = cv2.VideoCapture(0)

while True:
    ret, img = cam.read()
    if not ret:
        break

    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.2, 5)

    for (x,y,w,h) in faces:
        id, confidence = recognizer.predict(gray[y:y+h, x:x+w])
        cv2.rectangle(img, (x,y), (x+w,y+h), (0,255,0), 2)
        cv2.putText(img, f"User {id}", (x,y-10),
                    cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0,255,0), 2)

    cv2.imshow("Face Recognition", img)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cam.release()
cv2.destroyAllWindows()

# %%
# !find . -name "Face_Recognition_Project.ipynb"
